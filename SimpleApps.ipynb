# %%
# Count character occurrences in a given word, phrase or sentence

def charCount(s):
    # create an empty dictionary 
    charLib=dict()
    for i in s:
        if i not in charLib:
            charLib[i]=0
        charLib[i]+=1
    return charLib

#test function
occurrences= charCount("ASHIOYA LOVES DATA SCIENCE")
occurrences.pop(' ') # to delete space character if it is in dictionary
for char,occur in occurrences.items():
    print(char+" contains "+str(occur)+" times ")
# Out:
# A contains 4 times
# S contains 3 times
# H contains 1 times
# I contains 2 times
# O contains 2 times
# Y contains 1 times
# L contains 1 times
# V contains 1 times
# E contains 3 times
# D contains 1 times
# T contains 1 times
# C contains 2 times
# N contains 1 times

# %%
import re

addressToVerify ='victorashioya960@gmail.com'
match = re.match('^[_a-z0-9-]+(\.[_a-z0-9-]+)*@[a-z0-9-]+(\.[a-z0-9-]+)*(\.[a-z]{2,4})$', addressToVerify)

if match == None:
    print('Bad Syntax')
    raise ValueError('Bad Syntax')

# %%
import webbrowser
from tinkter import*
root = Tk()
root.title("Webbrowser")
root.geometry("300*200")
def google():
    webbbrowser.open("www.google.com")
mygoogle = Button(root, text="Open Google", command=google).pack(paddy=20)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-0f8b2c50a637> in <module>
#       1 import webbrowser
# ----> 2 from tinkter import*
#       3 root = Tk()
#       4 root.title("Webbrowser")
#       5 root.geometry("300*200")
#
# ModuleNotFoundError: No module named 'tinkter'

# %%
# Alarm clock
from datetime import datetime
from playsound import playsound
alarm_time = input("Set alarm: HH:MM:SS\n ")
alarm_hour = alarm_time[0:2]
alarm_min = alarm_time[3:5]
alarm_seconds = alarm_time[6:8]
alarm_period = alarm_time[9:11].upper()
print("Setting up alarm...")
while True:
    now = datetime.now()
    current_hour = now.strftime("%I")
    current_min = now.strftime("%M")
    current_seconds = now.strftime("%S")
    current_period = now.strftime("%p")
    if(alarm_period==current_period):
        if(alarm_hour==current_hour):
            if(alarm_min==current_min):
                if(alarm_seconds==current_seconds):
                    print("Wake up!")
                    playsound("audio.mp3")
                    break
# Out:
# Set alarm: HH:MM:SS
#  09:09:09
# Setting up alarm...
